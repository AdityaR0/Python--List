# %%
Python- List  Assignment Questions:

Q1. Create an empty list.

Ans:)
a = []         
print("Values of a:", a)

Q2. Create a list and add an element to the end of this list.

Ans:)
fruit_list = ["Apple", "Banana"]
print(f'Current Fruits List {fruit_list}')
new_fruit = input("Please enter a fruit name:\n")
fruit_list.append(new_fruit)
print(f'Updated Fruits List {fruit_list}')

Q3. For the above created list print the last element.

Ans:)
# input list
fruit_list = ["Apple", "Banana"]
# printing input list
print("Input list:", fruit_list)
# getting the last element of the list using slicing
lastElement = fruit_list[-1:]
# printing the last element of the list
print("Last element of the input list = ",lastElement)

Q4. Reverse the above created list.?

Ans:)
# Reversing a list
fruit_list = ["Apple", "Banana"]
print('Original list: ', fruit_list)

fruit_list.reverse()
print('Reversed list: ', fruit_list)

Q5. Sort the above created list.?

Ans:)
# a list of fruits
fruit_list = ["Apple", "Banana","5","2","0","1"]
#sort list in-place in ascending order
fruit_list.sort()
#print modified list
print(fruit_list)

Q6. Create a list of your top three favorite movies, then print the second movie title.?

Ans:)
# a list of Movies
Movies_list = ["KGF", "Puspa","Animal"]
# printing the middle element of the list
a=(Movies_list[1])
#print modified list
print(a)

Q7. Create a list of your favorite animals, then add a new animal to the list and print the updated list?

Ans:)
# a list of favorite animals
Animals_list = ["Lion", "Tiger","Dog","Cat","Horse"]
print(Animals_list)
#Adding the element of the list
Animals_list.append("Cow")
#print modified list
print(Animals_list)

Q8. Create a list of your favorite cities, then use the index() method to find the position of a specific city
on the list and print it?

Ans:)
# list of cities
Cities= ["Dhanbad", "Ranchi", "Kolkata","Patna","Bhopal","Asansol","Noida"] 
# searching positiion of cities
print(Cities.index("Kolkata"))
